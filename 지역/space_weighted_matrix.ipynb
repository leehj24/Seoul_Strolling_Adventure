# %%
import pandas as pd

file = r'E:\machin-prj\지역\수도권_지역.xlsx'
df = pd.read_excel(file)

df
# Out:
#                                addr1  ... zipcode
# 0            서울특별시 송파구 새말로 114 (문정동)  ...    5810
# 1           서울특별시 성동구 무학로6길 22 (도선동)  ...    4707
# 2        서울특별시 강서구 마곡중앙로 161-8 (마곡동)  ...    7788
# 3      서울특별시 성북구 동소문로20다길 30 (동선동1가)  ...    2845
# 4          서울특별시 강북구 도봉로68길 36 (미아동)  ...    1132
# ...                              ...  ...     ...
# 14128           경기도 화성시 효행로1265번길 76  ...   18383
# 14129           경기도 화성시 효행로1374번길 24  ...   18382
# 14130      경기도 화성시 효행로481번길 21 (안녕동)  ...   18345
# 14131      경기도 화성시 효행로481번길 21 (안녕동)  ...   18345
# 14132            경기도 화성시 효행로707번길 30  ...   18362
#
# [14133 rows x 21 columns]
